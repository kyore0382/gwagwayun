# %% [markdown]
# <a href="https://colab.research.google.com/github/kyore0382/gwagwayun/blob/main/Training_and_inference_using_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook shows you how to run training and inference on your own SLEAP dataset using the command-line interface.
#
# You'll use [Google Drive](https://www.google.com/drive) for moving your data to and from Colab. We'll guide you through the process.

# %% [markdown]
# # Installation
#
# Before we install SLEAP we need to set Colab to use TensorFlow 2.

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# Let's confirm that we have a GPU available. This next line should return something like "/device:GPU:0". If you instead see an empty string as the result, go to "Notebook settings" in the "Edit" menu and select "GPU" as the hardware accelerator.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# Now let's use `pip` to install SLEAP from PyPI.
#
# Note: This installation method should also work on other Linux machines, such as an HPC cluster, or on any system where you aren't planning to use a GPU. To use a GPU on a Windows machine you'll need to install using `conda`.

# %%
# !pip uninstall -y opencv-python opencv-contrib-python
# !pip install sleap==1.3.3
# Out:
# Found existing installation: opencv-python 4.13.0.92
# Uninstalling opencv-python-4.13.0.92:
#   Successfully uninstalled opencv-python-4.13.0.92
# Found existing installation: opencv-contrib-python 4.13.0.92
# Uninstalling opencv-contrib-python-4.13.0.92:
#   Successfully uninstalled opencv-contrib-python-4.13.0.92
# Collecting sleap==1.3.3
#   Downloading sleap-1.3.3-py3-none-any.whl.metadata (17 kB)
# Collecting imgstore<0.3.0 (from sleap==1.3.3)
#   Downloading imgstore-0.2.9-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting ndx-pose (from sleap==1.3.3)
#   Downloading ndx_pose-0.2.2-py3-none-any.whl.metadata (12 kB)
# Collecting nixio>=1.5.3 (from sleap==1.3.3)
#   Downloading nixio-1.5.4.tar.gz (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 63.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting qimage2ndarray (from sleap==1.3.3)
#   Downloading qimage2ndarray-1.10.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting segmentation-models (from sleap==1.3.3)
#   Downloading segmentation_models-1.0.1-py3-none-any.whl.metadata (938 bytes)
# Collecting pynwb>=2.3.3 (from sleap==1.3.3)
#   Downloading pynwb-3.1.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from imgstore<0.3.0->sleap==1.3.3) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from imgstore<0.3.0->sleap==1.3.3) (2.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from imgstore<0.3.0->sleap==1.3.3) (2.9.0.post0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from imgstore<0.3.0->sleap==1.3.3) (2025.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from imgstore<0.3.0->sleap==1.3.3) (6.0.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from imgstore<0.3.0->sleap==1.3.3) (5.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from nixio>=1.5.3->sleap==1.3.3) (3.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from nixio>=1.5.3->sleap==1.3.3) (1.17.0)
# Collecting hdmf<5,>=4.1.2 (from pynwb>=2.3.3->sleap==1.3.3)
#   Downloading hdmf-4.3.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: platformdirs>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from pynwb>=2.3.3->sleap==1.3.3) (4.9.6)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models->sleap==1.3.3)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Collecting image-classifiers==1.0.0 (from segmentation-models->sleap==1.3.3)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models->sleap==1.3.3)
#   Downloading efficientnet-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (0.25.2)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3) (4.26.0)
# Collecting ruamel-yaml>=0.16 (from hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3)
#   Downloading ruamel_yaml-0.19.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->imgstore<0.3.0->sleap==1.3.3) (2026.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3) (0.30.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (2026.4.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (26.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models->sleap==1.3.3) (0.5)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema>=3.2.0->hdmf<5,>=4.1.2->pynwb>=2.3.3->sleap==1.3.3) (4.15.0)
# Downloading sleap-1.3.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.8 MB/s eta 0:00:00
# Downloading imgstore-0.2.9-py2.py3-none-any.whl (904 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.1/904.1 kB 61.3 MB/s eta 0:00:00
# Downloading pynwb-3.1.3-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.8 MB/s eta 0:00:00
# Downloading ndx_pose-0.2.2-py3-none-any.whl (15 kB)
# Downloading qimage2ndarray-1.10.0-py3-none-any.whl (12 kB)
# Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading hdmf-4.3.1-py3-none-any.whl (341 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.9/341.9 kB 15.1 MB/s eta 0:00:00
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.0 MB/s eta 0:00:00
# Downloading ruamel_yaml-0.19.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 14.0 MB/s eta 0:00:00
# Building wheels for collected packages: nixio
#   Building wheel for nixio (setup.py) ... done
#   Created wheel for nixio: filename=nixio-1.5.4-py3-none-any.whl size=87927 sha256=e8ae2dd48c8f82e7bbb483e6876b5c49f853bde0cbc958c3dba8b9b7d805c1f8
#   Stored in directory: /root/.cache/pip/wheels/9b/1d/76/1abd6ceaa9258868c846daefc4ba7a9494d6383af9ad779f66
# Successfully built nixio
# Installing collected packages: ruamel-yaml, qimage2ndarray, nixio, keras-applications, imgstore, image-classifiers, efficientnet, segmentation-models, hdmf, pynwb, ndx-pose, sleap
# Successfully installed efficientnet-1.0.0 hdmf-4.3.1 image-classifiers-1.0.0 imgstore-0.2.9 keras-applications-1.0.8 ndx-pose-0.2.2 nixio-1.5.4 pynwb-3.1.3 qimage2ndarray-1.10.0 ruamel-yaml-0.19.1 segmentation-models-1.0.1 sleap-1.3.3

# %% [markdown]
# ## Getting your training data into Colab
#
# You'll need to get your training data into Colab. The easiest way to do this is to export a self-contained **training package** from SLEAP and copy that on to [Google Drive](https://www.google.com/drive).
#
# Let's first mount your Google Drive so that it can be accessed from Colab. You'll be prompted to log into your Google account, give Colab access, and the copy an authorization code into a field below.

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Now let's create a training package and copy it into your Google Drive.
#
# A training package contains both labeled data as well as the labeled images which will be used for training. One advantage to training packages is that it doesn't depend on paths to other files (i.e., videos) to be messed up when you copy your project to another volume.
#
# See [this guide](https://sleap.ai/guides/training-package.html) for exporting a training package from SLEAP.
#
#
#
# The following cell sets your current working directory to the directory with your training package. This will ensure that the output from training (i.e., the models) and from interence (i.e., predictions) will all be saved in this directory.
#
# **Important**: For this demo, I'll assume you have a `sleap` directory in the root of your Google drive and you place the exported training package in that directory with the filename `colab.pkg.slp`. If you placed your training pckage somewhere else, you'll need to adjust the path below.

# %%
import os
os.chdir('/content/drive/MyDrive/sleap')
# !ls
# Out:
# colab.pkg.slp

# %%
# !pip install cattrs==22.2.0
# !pip install opencv-python-headless==4.8.1.78 --force-reinstall
# !python -c "import cv2; print(cv2.__version__)"
# Out:
# Requirement already satisfied: cattrs==22.2.0 in /usr/local/lib/python3.12/dist-packages (22.2.0)
# Requirement already satisfied: attrs>=20 in /usr/local/lib/python3.12/dist-packages (from cattrs==22.2.0) (26.1.0)
# Collecting opencv-python-headless==4.8.1.78
#   Using cached opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting numpy>=1.21.2 (from opencv-python-headless==4.8.1.78)
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Using cached opencv_python_headless-4.8.1.78-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 110.9 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python-headless
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires opencv-python>=3.4.8.29, which is not installed.
# albucore 0.0.24 requires opencv-python-headless>=4.9.0.80, but you have opencv-python-headless 4.8.1.78 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.6 which is incompatible.
# albumentations 2.0.8 requires opencv-python-headless>=4.9.0.80, but you have opencv-python-headless 4.8.1.78 which is incompatible.
# Successfully installed numpy-2.4.6 opencv-python-headless-4.8.1.78
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<string>", line 1, in <module>
#   File "/usr/local/lib/python3.12/dist-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/usr/local/lib/python3.12/dist-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# AttributeError: _ARRAY_API not found
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/local/lib/python3.12/dist-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/usr/local/lib/python3.12/dist-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/importlib/__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# ## Training
#
# Now you're ready to train a model! We'll use the command-line interface for training, and train a model for confidence maps using the default **training profile**. The training profile determines the model architecture, the learning rate for training, and other training hyperparameters.
#
# When you start running this cell, you'll see the training parameters listed and then you'll see the training and validation loss for each training epoch.
#
# If you're happy with the validation loss you see for an epoch during training, you're welcome to stop training by clicking the stop button next to the notebook cell running training. The version of the model with the lowest validation loss is saved during training, and that's what will be used for inference. If you don't stop training, it will run for 200 epochs, or until validation loss fails to improve for some number of epochs (controlled by the `early_stopping` parameter in the training profile).
#
# **Important**: If your training package isn't named `colab.pkg.slp`, you'll need to adjust the name below.

# %% [markdown]
# Once training finishes, you'll have a trained model for confidence maps on your Google Drive. There will be a `models/` directory inside your `sleap/` directory (or wherever you had the training package), and inside this there will be a `colab_demo.bottomup` directory (the name of this directory was set by the `--run_name` parameter).
#
# This `colab_demo.bottomup` directory contains all the files SLEAP needs to use this model. You can copy it to a local drive if you want to use it for running inference from the SLEAP GUI, copy it to a network drive if you want to run inference from an HPC cluster, or leave it on your Google Drive if you want to run inference on Colab... as we'll do below.

# %% [markdown]
# ## Training other models
#
# The **bottomup** model you trained above can be used for "bottom up" inference. You can also train a **centroid** model and a **centered instance** model for "top down" inference. See [here](https://sleap.ai/#getting-started-with-sleap) for more information about these two different approaches.
#
# Here's how to train centroid and centered instance models using the default training settings:

# %%
# !pip install cattrs==22.2.0
# Out:
# Collecting cattrs==22.2.0
#   Downloading cattrs-22.2.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: attrs>=20 in /usr/local/lib/python3.12/dist-packages (from cattrs==22.2.0) (26.1.0)
# Downloading cattrs-22.2.0-py3-none-any.whl (35 kB)
# Installing collected packages: cattrs
# Successfully installed cattrs-22.2.0

# %%
# !sed -i 's/if cv2.__version__.startswith/if getattr(cv2, "__version__", "4.").startswith/' /usr/local/lib/python3.12/dist-packages/imgstore/util.py

# %%
# !sleap-train baseline.centroid.json colab.pkg.slp --run_name "colab_demo.centroid"
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# Traceback (most recent call last):
#   File "/usr/local/bin/sleap-train", line 5, in <module>
#     from sleap.nn.training import main
#   File "/usr/local/lib/python3.12/dist-packages/sleap/__init__.py", line 10, in <module>
#     from sleap.io.dataset import Labels, load_file
#   File "/usr/local/lib/python3.12/dist-packages/sleap/io/dataset.py", line 72, in <module>
#     from sleap.instance import (
#   File "/usr/local/lib/python3.12/dist-packages/sleap/instance.py", line 32, in <module>
#     from sleap.io.video import Video
#   File "/usr/local/lib/python3.12/dist-packages/sleap/io/video.py", line 8, in <module>
#     import imgstore
#   File "/usr/local/lib/python3.12/dist-packages/imgstore/__init__.py", line 1, in <module>
#     from .stores import new_for_filename, new_for_format, extract_only_frame, get_supported_formats,\
#   File "/usr/local/lib/python3.12/dist-packages/imgstore/stores.py", line 38, in <module>
#     from .util import ImageCodecProcessor, JsonCustomEncoder, FourCC, ensure_color,\
#   File "/usr/local/lib/python3.12/dist-packages/imgstore/util.py", line 11, in <module>
#     if cv2.__version__.startswith(('3.', '4.')):
#        ^^^^^^^^^^^^^^^
# AttributeError: module 'cv2' has no attribute '__version__'

# %%
# !sleap-train baseline_medium_rf.topdown.json --run_name "colab_demo.topdown_confmaps"

# %%
# !sleap-train baseline.centroid.json colab.pkg.slp --run_name "colab_demo.centroid"

# %% [markdown]
# # Inference
#
# At this point you should have SLEAP installed, your Google Drive mounted, and trained models saved on your Google Drive. If you've been working through the notebook, you should have a `models` subdirectory inside your current working directory. Let's take a look:

# %%
# !ls models

# %% [markdown]
# We'll also need a video for which we want predictions. Copy the video onto your Google drive.
#
# For this demo we'll just get predictions for the first 200 frames (or you can adjust the `--frames` parameter below or remove it to run on the whole video).
#
# **Important**: If your video is not named `colab_demo.mp4`, change this in the following cell to match the name of your video. If you trained top-down models and not a bottom-up model, see the end of the notebook for how to run inference with the pair of top-down models.

# %%
# !sleap-track colab_demo.mp4 \
    --frames 0-200 \
    --tracking.tracker simple \
    -m models/colab_demo.bottomup

# %% [markdown]
# When inference is finished, it will save the predictions in a file which can be opened in the GUI as a SLEAP project file. The file will be in the same directory as the video and the filename will be `{video filename}.predictions.slp`.
#
# Let's inspect the predictions file:

# %%
# !sleap-inspect colab_demo.mp4.predictions.slp

# %% [markdown]
# You can copy this file from your Google Drive to a local drive and open it in the SLEAP GUI app (or open it directly if you have your Google Drive mounted on your local machine). If the video is in the same directory as the predictions file, SLEAP will automatically find it; otherwise, you'll be prompted to locate the video (since the path to the video on your local machine will be different than the path to the video on Colab).

# %% [markdown]
# ## Inference parameters
#
# One important option when running inference is whether (and how) you want to track instance identities. If you omit `--tracking.tracker flow` then the identities will not be tracked. Tracking methods/options are explained [here](https://sleap.ai/guides/proofreading.html#tracking-methods).
#
# You can see all of the command-line arguments by calling `sleap-track` with the `--help` argument, like so:

# %%
# !sleap-track --help

# %% [markdown]
# ## Inference with top-down models
#
# If you trained the pair of models needed for top-down inference, you can call `sleap-track` with `-m path/to/model` for each model, like so:

# %%
# !sleap-track colab_demo.video.mp4 \
    --frames 0-200 \
    --tracking.tracker simple \
    -m models/colab_demo.topdown_confmaps \
    -m models/colab_demo.centroid
